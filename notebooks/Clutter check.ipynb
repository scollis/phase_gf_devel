# %%
import pyart
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
cfile = pyart.io.read('/ssd_data/clutter_files/march_i4_crazy.nc')

# %%
cfile.fields.keys()
# Out:
# dict_keys(['xsapr_clutter'])

# %%
myd = pyart.graph.RadarDisplay(cfile)

# %%
figm = plt.figure(figsize=[10,8])
myd.plot_ppi('xsapr_clutter', 1)

# %%
poop = cfile.get_gate_x_y_z(0)

# %%
im_high = cfile.gate_z['data'] > 1500.

# %%
cfile.fields['xsapr_clutter']['data'][im_high] = 0.

# %%
myd = pyart.graph.RadarDisplay(cfile)
figm = plt.figure(figsize=[10,8])
myd.plot_ppi('xsapr_clutter', 1)

# %%
cfile.elevation['data'][0]
# Out:
# -0.2856558

# %%
poop[2].min()
# Out:
# -111.0

# %%
pyart.io.write_cfradial('/ssd_data/clutter_files/modified_march.nc', cfile)
